# %%
import sys
sys.path.append('../src')

# %%
import competencia_cocina
import estadisticas_texto

# %%
print("Ejercicio 10: competencia de cocina")
print()
competencia_cocina.competencia()
print()
print("Ejercicio 1: estadisticas de texto")
print()
estadisticas_texto.stats()
print()
